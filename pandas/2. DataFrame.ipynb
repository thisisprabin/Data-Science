# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_csv('stoneFlakes.csv')

# %%
nfl_frame
# Out:
#      ID   LBI    RTI   WDI  FLA   PSF   FSF  ZDF1  PROZD  GROUP
# 0    ar     ?  35.30  2.60    ?  42.4  24.2  47.1     69      3
# 1   arn  1.23  27.00  3.59  122     0    40    40     30      2
# 2    be  1.24  26.50  2.90  121    16  20.7  29.7     72      2
# 3   bi1  1.07  29.10  3.10  114    44   2.6  26.3     68      1
# 4   bi2  1.08  43.70  2.40  105  32.6   5.8  10.7     42      1
# 5   bie  1.39  29.50  2.78  126    14     0    50     78      2
# 6    bn  1.31  26.30  2.10  119  15.7  15.7  30.4     72      2
# 7    bo  1.27  27.60  3.50  116  16.8    23  35.2     69      2
# 8    by  1.11  32.60  2.90  113  15.8  15.8    15     57      2
# 9     c  1.32  29.50  2.57  121    22     2    18     63      3
# 10   cl  1.16  33.40  2.30  131   7.5  14.9     6     60      1
# 11    d  1.23  27.60  2.83  121  27.9   6.7  31.7     67      2
# 12   e1  1.24  25.50  3.60  113   5.3  21.1    60     86      3
# 13   e2   1.2  27.70  3.40  108  37.4   9.9  39.9     71      3
# ...

# %%
nfl_frame.columns
# Out:
# Index(['ID', 'LBI', 'RTI', 'WDI', 'FLA', 'PSF', 'FSF', 'ZDF1', 'PROZD',
#        'GROUP'],
#       dtype='object')

# %%
# Selecting specific columns
DataFrame(nfl_frame, columns=['ID','LBI','RTI','WDI'])
# Out:
#      ID   LBI    RTI   WDI
# 0    ar     ?  35.30  2.60
# 1   arn  1.23  27.00  3.59
# 2    be  1.24  26.50  2.90
# 3   bi1  1.07  29.10  3.10
# 4   bi2  1.08  43.70  2.40
# 5   bie  1.39  29.50  2.78
# 6    bn  1.31  26.30  2.10
# 7    bo  1.27  27.60  3.50
# 8    by  1.11  32.60  2.90
# 9     c  1.32  29.50  2.57
# 10   cl  1.16  33.40  2.30
# 11    d  1.23  27.60  2.83
# 12   e1  1.24  25.50  3.60
# 13   e2   1.2  27.70  3.40
# 14   ey  1.33  29.40  2.30
# 15  fli  1.11  35.10  3.51
# 16  g10  1.14  29.90  2.90
# 17  g11  1.16  27.90  3.00
# 18   g2  1.22  29.50  3.00
# 19   g4  1.23  29.00  2.90
# 20   g5  1.25  30.20  2.80
# 21   g6  1.19  31.60  2.40
# 22  ga1  1.11  21.80  3.60
# 23  ga2  1.22  34.20  2.60
# 24  goe  1.07  19.80  4.15
# 25  gra  1.31  19.50  3.83
# 26  gro  1.24  36.00  3.36
# 27  gue  1.17  31.50  2.52
# 28  hey  1.11  28.30  2.50
# 29   hu  1.41  23.80  3.20
# ..  ...   ...    ...   ...
# 49  roe  1.26  27.50  2.41
# 50   s1  1.03  23.30  3.50
# ...

# %%
# Selecting starting rows
# Bydefault it returns first 5 rows
nfl_frame.head()
# Out:
#     ID   LBI   RTI   WDI  FLA   PSF   FSF  ZDF1  PROZD  GROUP
# 0   ar     ?  35.3  2.60    ?  42.4  24.2  47.1     69      3
# 1  arn  1.23  27.0  3.59  122     0    40    40     30      2
# 2   be  1.24  26.5  2.90  121    16  20.7  29.7     72      2
# 3  bi1  1.07  29.1  3.10  114    44   2.6  26.3     68      1
# 4  bi2  1.08  43.7  2.40  105  32.6   5.8  10.7     42      1

# %%
nfl_frame.head(3)
# Out:
#     ID   LBI   RTI   WDI  FLA   PSF   FSF  ZDF1  PROZD  GROUP
# 0   ar     ?  35.3  2.60    ?  42.4  24.2  47.1     69      3
# 1  arn  1.23  27.0  3.59  122     0    40    40     30      2
# 2   be  1.24  26.5  2.90  121    16  20.7  29.7     72      2

# %%
# Selecting ending rows
# Bydefault it selects 5 rows 
nfl_frame.tail()
# Out:
#      ID   LBI   RTI   WDI  FLA   PSF   FSF  ZDF1  PROZD  GROUP
# 74   wn  1.04  30.4  2.70  118  33.3   5.1  28.2     66      1
# 75  woe  1.14  31.9  2.07  121    15    10     5     47      1
# 76  wol  1.24  27.2  3.00  120  29.1  13.8  34.4     70      2
# 77  wst  1.15  38.0  2.25  125   9.5   6.4    13     88      2
# 78    z  1.37  26.0  3.22  125  12.6  21.5  28.6     61      2

# %%
# Specific index value
nfl_frame.ix[3]
# Out:
# /home/riju/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ID        bi1
# LBI      1.07
# RTI      29.1
# WDI       3.1
# FLA       114
# PSF        44
# FSF       2.6
# ZDF1     26.3
# PROZD      68
# GROUP       1
# Name: 3, dtype: object

# %%
# Creating column and fieling with value
nfl_frame['state'] = 0

# %%
nfl_frame
# Out:
#      ID   LBI    RTI   WDI  FLA   PSF   FSF  ZDF1  PROZD  GROUP  state
# 0    ar     ?  35.30  2.60    ?  42.4  24.2  47.1     69      3      0
# 1   arn  1.23  27.00  3.59  122     0    40    40     30      2      0
# 2    be  1.24  26.50  2.90  121    16  20.7  29.7     72      2      0
# 3   bi1  1.07  29.10  3.10  114    44   2.6  26.3     68      1      0
# 4   bi2  1.08  43.70  2.40  105  32.6   5.8  10.7     42      1      0
# 5   bie  1.39  29.50  2.78  126    14     0    50     78      2      0
# 6    bn  1.31  26.30  2.10  119  15.7  15.7  30.4     72      2      0
# 7    bo  1.27  27.60  3.50  116  16.8    23  35.2     69      2      0
# 8    by  1.11  32.60  2.90  113  15.8  15.8    15     57      2      0
# 9     c  1.32  29.50  2.57  121    22     2    18     63      3      0
# 10   cl  1.16  33.40  2.30  131   7.5  14.9     6     60      1      0
# 11    d  1.23  27.60  2.83  121  27.9   6.7  31.7     67      2      0
# ...

# %%
# Creating a series and adding it to the list 
state = Series(["Done", "Not Done"], index=[4, 0])
state
# Out:
# 4        Done
# 0    Not Done
# dtype: object

# %%
# Adding it to the list
nfl_frame['State'] = state
nfl_frame
# Out:
#      ID   LBI    RTI   WDI  FLA   PSF   FSF  ZDF1  PROZD  GROUP  state  \
# 0    ar     ?  35.30  2.60    ?  42.4  24.2  47.1     69      3      0
# 1   arn  1.23  27.00  3.59  122     0    40    40     30      2      0
# 2    be  1.24  26.50  2.90  121    16  20.7  29.7     72      2      0
# 3   bi1  1.07  29.10  3.10  114    44   2.6  26.3     68      1      0
# 4   bi2  1.08  43.70  2.40  105  32.6   5.8  10.7     42      1      0
# 5   bie  1.39  29.50  2.78  126    14     0    50     78      2      0
# 6    bn  1.31  26.30  2.10  119  15.7  15.7  30.4     72      2      0
# 7    bo  1.27  27.60  3.50  116  16.8    23  35.2     69      2      0
# 8    by  1.11  32.60  2.90  113  15.8  15.8    15     57      2      0
# 9     c  1.32  29.50  2.57  121    22     2    18     63      3      0
# 10   cl  1.16  33.40  2.30  131   7.5  14.9     6     60      1      0
# 11    d  1.23  27.60  2.83  121  27.9   6.7  31.7     67      2      0
# ...

# %%
# Deleting spacific column
del nfl_frame['State']
nfl_frame
# Out:
#      ID   LBI    RTI   WDI  FLA   PSF   FSF  ZDF1  PROZD  GROUP  state
# 0    ar     ?  35.30  2.60    ?  42.4  24.2  47.1     69      3      0
# 1   arn  1.23  27.00  3.59  122     0    40    40     30      2      0
# 2    be  1.24  26.50  2.90  121    16  20.7  29.7     72      2      0
# 3   bi1  1.07  29.10  3.10  114    44   2.6  26.3     68      1      0
# 4   bi2  1.08  43.70  2.40  105  32.6   5.8  10.7     42      1      0
# 5   bie  1.39  29.50  2.78  126    14     0    50     78      2      0
# 6    bn  1.31  26.30  2.10  119  15.7  15.7  30.4     72      2      0
# 7    bo  1.27  27.60  3.50  116  16.8    23  35.2     69      2      0
# 8    by  1.11  32.60  2.90  113  15.8  15.8    15     57      2      0
# 9     c  1.32  29.50  2.57  121    22     2    18     63      3      0
# 10   cl  1.16  33.40  2.30  131   7.5  14.9     6     60      1      0
# 11    d  1.23  27.60  2.83  121  27.9   6.7  31.7     67      2      0
# ...

# %%
# Deleting spacific column
del nfl_frame['state']
nfl_frame
# Out:
#      ID   LBI    RTI   WDI  FLA   PSF   FSF  ZDF1  PROZD  GROUP
# 0    ar     ?  35.30  2.60    ?  42.4  24.2  47.1     69      3
# 1   arn  1.23  27.00  3.59  122     0    40    40     30      2
# 2    be  1.24  26.50  2.90  121    16  20.7  29.7     72      2
# 3   bi1  1.07  29.10  3.10  114    44   2.6  26.3     68      1
# 4   bi2  1.08  43.70  2.40  105  32.6   5.8  10.7     42      1
# 5   bie  1.39  29.50  2.78  126    14     0    50     78      2
# 6    bn  1.31  26.30  2.10  119  15.7  15.7  30.4     72      2
# 7    bo  1.27  27.60  3.50  116  16.8    23  35.2     69      2
# 8    by  1.11  32.60  2.90  113  15.8  15.8    15     57      2
# 9     c  1.32  29.50  2.57  121    22     2    18     63      3
# 10   cl  1.16  33.40  2.30  131   7.5  14.9     6     60      1
# 11    d  1.23  27.60  2.83  121  27.9   6.7  31.7     67      2
# 12   e1  1.24  25.50  3.60  113   5.3  21.1    60     86      3
# 13   e2   1.2  27.70  3.40  108  37.4   9.9  39.9     71      3
# ...

# %%
# Creating Dataframe from dictionary
data = {'City':['LA', 'SF', 'NYC'], 'Population':[21000, 32000, 55000]}
city_frame = DataFrame(data)
city_frame
# Out:
#   City  Population
# 0   LA       21000
# 1   SF       32000
# 2  NYC       55000
